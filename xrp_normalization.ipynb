# %% [markdown]
# <a href="https://colab.research.google.com/github/youjinlee430/introduction-to-ML/blob/main/xrp_normalization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv ("/content/drive/MyDrive/Machine learning/Cleaned Data.csv", index_col= 0)

# %%
df.head()
# Out:
#                 open      high       low     close       volume  label
# timeOpen
# 2022/12/31  0.345032  0.345100  0.339868  0.339929  337167277.7      1
# 2022/12/30  0.342831  0.345313  0.335333  0.345017  672119601.9      0
# 2022/12/29  0.356524  0.357225  0.338911  0.342846  898022518.4      1
# 2022/12/28  0.368122  0.368543  0.356136  0.356531  839617675.9      1
# 2022/12/27  0.365728  0.372270  0.359441  0.368126  905248563.4      0

# %%
print(df.shape)
print(df.dtypes)
# Out:
# (1096, 5)
# open      float64
# high      float64
# low       float64
# close     float64
# volume    float64
# dtype: object

# %%
dfx = df[['open','high','low', 'close','volume']]

# %%
def MinMaxScaler(data):
    """최솟값과 최댓값을 이용하여 0 ~ 1 값으로 변환"""
    numerator = data - np.min(data, 0)
    denominator = np.max(data, 0) - np.min(data, 0)
    # 0으로 나누기 에러가 발생하지 않도록 매우 작은 값(1e-7)을 더해서 나눔
    return numerator / (denominator + 1e-7)

# %%
dfx = df[['open','high','low', 'close','volume']]
dfx = MinMaxScaler(dfx)
dfy = dfx[['close']]
dfx = dfx[['open','high','low', 'volume']]
dfx
# Out:
#                 open      high       low    volume
# timeOpen
# 2022/12/31  0.120529  0.109010  0.145673  0.003043
# 2022/12/30  0.119231  0.109127  0.142734  0.012163
# 2022/12/29  0.127301  0.115679  0.145053  0.018313
# 2022/12/28  0.134137  0.121904  0.156216  0.016723
# 2022/12/27  0.132726  0.123954  0.158358  0.018510
# ...              ...       ...       ...       ...
# 2020/01/05  0.031732  0.028773  0.051063  0.025665
# 2020/01/04  0.031234  0.026259  0.049736  0.021071
# 2020/01/03  0.027950  0.025939  0.045854  0.028441
# 2020/01/02  0.030755  0.025293  0.046567  0.023413
# 2020/01/01  0.030875  0.026099  0.049912  0.022209
#
# [1096 rows x 4 columns]
